# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import lightgbm as lgb
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import pickle
import time
import gc

from multiprocessing import *
from xgboost import XGBClassifier
#from lightgbm import LBGMClassifier
from sklearn import *
from numba import jit
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
DATA_TRAIN_PATH = './Data/train.csv'
DATA_TEST_PATH =  './Data/test.csv'


def load_data(train_path = DATA_TRAIN_PATH, test_path = DATA_TEST_PATH):
    train = pd.read_csv(train_path, na_values = "-1")
    test = pd.read_csv(test_path, na_values = "-1")
    
    x_train = train.drop(['target', 'id'], axis = 1)
    y_train = train['target']
    id_train = train['id'].values
    print('Train data shape: ', x_train.shape)
    
    x_test = test.drop(['id'], axis = 1)
    id_test = test['id'].values
    print('Test data shape: ', x_test.shape)   
    
    return x_train, y_train, id_train, x_test, id_test

def feature_info(df):
    cat_features = df.columns[df.columns.str.endwith('cat')].tolist()
    bin_features = df.columns[df.columns.str.endwith('bin')].tolist()
    num_features = [feature for feature in df.columns.tolist() 
                    if feature not in cat_features and features not in bin_features]
    return cat_features, bin_features, num_features

def submit(filename, id_test, pred_test):
    sub = pd.DataFrame()
    sub['id'] = id_test
    sub['target'] = pred_test
    sub.to_csv(filename, index = False)

def gini(y_true, y_prob):
    y_true = np.asarray(y_true)
    y_true = y_true[np.argsort(y_prob)]
    ntrue = 0
    gini = 0
    delta = 0
    n = len(y_true)
    for i in range(n-1, -1, -1):
        y_i = y_true[i]
        ntrue += y_i
        gini += y_i * delta
        delta += 1 - y_i
    gini = 1 - 2 * gini / (ntrue * (n - ntrue))
    return gini

def gini_normalized(y_true, y_pred):
    return gini(y_true, y_pred)/gini(y_true, y_true)

def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return[('gini', gini_score)]

def gini_lgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return 'gini', gini_score, True    
    
def add_noise(series, noise_level):
    return series*( 1+ noise_level * np.random.randn(len(series)))

# %%
# params = {'objective' : 'binary:logistic',
#           'eta' : 0.015, 
#           'silent' : False,
#           'max_depth' : 7, 
#           'subsample' : 0.9,
#           'colsample_bytree' : 0.9
# }

params = {'eta': 0.02, 
          'max_depth': 5, 
          'subsample': 0.9, 
          'colsample_bytree': 0.9, 
          'objective': 'binary:logistic', 
          'eval_metric': 'auc', 
          'seed': 99, 
          'silent': True}

# %%
x_train, y_train, id_train, x_test, id_test = load_data(train_path = DATA_TRAIN_PATH, test_path = DATA_TEST_PATH)
# Out:
# Train data shape:  (595212, 57)
# Test data shape:  (892816, 57)

# %%
kfold = 5
stratkfold = StratifiedKFold(n_splits=kfold, random_state=0, shuffle = True)
y_pred = np.zeros((x_test.shape[0], ))
num_round = 2000

# %%
for i, (train_index, test_index) in enumerate(stratkfold.split(x_train, y_train)):
    print(' xgb kfold: {}  of  {} : '.format(i+1, kfold))    
    d_train = xgb.DMatrix(x_train.iloc[train_index], y_train.iloc[train_index]) 
    d_valid = xgb.DMatrix(x_train.iloc[test_index], y_train.iloc[test_index]) 
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    
    model = xgb.train(params, d_train, num_round, watchlist, early_stopping_rounds = 50, 
                  feval = gini_xgb, maximize = True, verbose_eval = 10)

    y_pred += model.predict(xgb.DMatrix(x_test), ntree_limit=(model.best_ntree_limit+50) )

pickle.dump(model, open("xgb_model.pickle.dat", "wb"))
# Out:
#  xgb kfold: 1  of  5 :
# [0]	train-gini:0.216161	valid-gini:0.205707
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 50 rounds.
# [10]	train-gini:0.246681	valid-gini:0.236489
# [20]	train-gini:0.255201	valid-gini:0.242475
# [30]	train-gini:0.255973	valid-gini:0.242937
# [40]	train-gini:0.257625	valid-gini:0.244077
# [50]	train-gini:0.261214	valid-gini:0.246571
# [60]	train-gini:0.26166	valid-gini:0.245787
# [70]	train-gini:0.263165	valid-gini:0.247258
# [80]	train-gini:0.264795	valid-gini:0.248616
# [90]	train-gini:0.266621	valid-gini:0.250027
# [100]	train-gini:0.267636	valid-gini:0.250143
# [110]	train-gini:0.268771	valid-gini:0.250526
# [120]	train-gini:0.270903	valid-gini:0.251459
# [130]	train-gini:0.27309	valid-gini:0.252376
# [140]	train-gini:0.276704	valid-gini:0.254462
# [150]	train-gini:0.278946	valid-gini:0.255162
# [160]	train-gini:0.283036	valid-gini:0.257442
# [170]	train-gini:0.28655	valid-gini:0.259284
# [180]	train-gini:0.290221	valid-gini:0.261468
# [190]	train-gini:0.293874	valid-gini:0.263509
# [200]	train-gini:0.297256	valid-gini:0.265116
# [210]	train-gini:0.300523	valid-gini:0.267148
# [220]	train-gini:0.303665	valid-gini:0.268292
# [230]	train-gini:0.306978	valid-gini:0.269601
# [240]	train-gini:0.309724	valid-gini:0.271033
# [250]	train-gini:0.312465	valid-gini:0.2722
# [260]	train-gini:0.315665	valid-gini:0.273859
# [270]	train-gini:0.31805	valid-gini:0.274746
# [280]	train-gini:0.32052	valid-gini:0.276006
# [290]	train-gini:0.323345	valid-gini:0.277211
# [300]	train-gini:0.325702	valid-gini:0.278071
# [310]	train-gini:0.328182	valid-gini:0.278927
# [320]	train-gini:0.330686	valid-gini:0.279604
# [330]	train-gini:0.33323	valid-gini:0.280734
# [340]	train-gini:0.335719	valid-gini:0.281451
# [350]	train-gini:0.338063	valid-gini:0.281908
# [360]	train-gini:0.340083	valid-gini:0.282531
# [370]	train-gini:0.342224	valid-gini:0.283103
# [380]	train-gini:0.344263	valid-gini:0.283211
# [390]	train-gini:0.346467	valid-gini:0.283415
# [400]	train-gini:0.348456	valid-gini:0.283871
# [410]	train-gini:0.350521	valid-gini:0.283906
# [420]	train-gini:0.35236	valid-gini:0.284161
# [430]	train-gini:0.354431	valid-gini:0.284643
# [440]	train-gini:0.356729	valid-gini:0.284797
# [450]	train-gini:0.358788	valid-gini:0.285078
# [460]	train-gini:0.360619	valid-gini:0.285201
# [470]	train-gini:0.362433	valid-gini:0.285382
# [480]	train-gini:0.364415	valid-gini:0.285524
# [490]	train-gini:0.366709	valid-gini:0.285629
# [500]	train-gini:0.368675	valid-gini:0.285995
# [510]	train-gini:0.37055	valid-gini:0.286242
# [520]	train-gini:0.372223	valid-gini:0.286197
# [530]	train-gini:0.374127	valid-gini:0.286404
# [540]	train-gini:0.375874	valid-gini:0.286529
# [550]	train-gini:0.377321	valid-gini:0.28651
# [560]	train-gini:0.378722	valid-gini:0.286383
# [570]	train-gini:0.38024	valid-gini:0.286405
# [580]	train-gini:0.382029	valid-gini:0.286444
# [590]	train-gini:0.383893	valid-gini:0.28662
# [600]	train-gini:0.385126	valid-gini:0.286626
# [610]	train-gini:0.386394	valid-gini:0.28661
# [620]	train-gini:0.388199	valid-gini:0.286643
# [630]	train-gini:0.389817	valid-gini:0.286743
# [640]	train-gini:0.391344	valid-gini:0.28681
# [650]	train-gini:0.392699	valid-gini:0.286713
# [660]	train-gini:0.394459	valid-gini:0.286847
# [670]	train-gini:0.395747	valid-gini:0.286833
# [680]	train-gini:0.397265	valid-gini:0.286823
# Stopping. Best iteration:
# [633]	train-gini:0.390417	valid-gini:0.286928
#
#  xgb kfold: 2  of  5 :
# [0]	train-gini:0.216039	valid-gini:0.208166
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 50 rounds.
# [10]	train-gini:0.246262	valid-gini:0.233922
# [20]	train-gini:0.25279	valid-gini:0.24146
# [30]	train-gini:0.254086	valid-gini:0.241964
# [40]	train-gini:0.255142	valid-gini:0.243103
# [50]	train-gini:0.257945	valid-gini:0.245374
# [60]	train-gini:0.25827	valid-gini:0.245986
# [70]	train-gini:0.259842	valid-gini:0.247487
# [80]	train-gini:0.26236	valid-gini:0.249316
# [90]	train-gini:0.263963	valid-gini:0.250302
# [100]	train-gini:0.265111	valid-gini:0.250155
# [110]	train-gini:0.267584	valid-gini:0.251842
# [120]	train-gini:0.271345	valid-gini:0.253748
# [130]	train-gini:0.274088	valid-gini:0.25523
# [140]	train-gini:0.278302	valid-gini:0.258009
# [150]	train-gini:0.282099	valid-gini:0.259322
# [160]	train-gini:0.285568	valid-gini:0.260279
# [170]	train-gini:0.289124	valid-gini:0.26237
# [180]	train-gini:0.292413	valid-gini:0.263976
# [190]	train-gini:0.296006	valid-gini:0.26499
# [200]	train-gini:0.299722	valid-gini:0.266563
# [210]	train-gini:0.302593	valid-gini:0.26684
# [220]	train-gini:0.305471	valid-gini:0.267714
# [230]	train-gini:0.308247	valid-gini:0.268675
# [240]	train-gini:0.310779	valid-gini:0.269483
# [250]	train-gini:0.313708	valid-gini:0.270672
# [260]	train-gini:0.31664	valid-gini:0.271241
# [270]	train-gini:0.319366	valid-gini:0.271868
# [280]	train-gini:0.322126	valid-gini:0.272205
# [290]	train-gini:0.324285	valid-gini:0.272724
# [300]	train-gini:0.326959	valid-gini:0.273313
# [310]	train-gini:0.329447	valid-gini:0.274013
# [320]	train-gini:0.331909	valid-gini:0.27452
# [330]	train-gini:0.334034	valid-gini:0.275452
# [340]	train-gini:0.336655	valid-gini:0.275904
# [350]	train-gini:0.338911	valid-gini:0.276443
# [360]	train-gini:0.341364	valid-gini:0.276766
# [370]	train-gini:0.343725	valid-gini:0.277301
# [380]	train-gini:0.345801	valid-gini:0.277365
# [390]	train-gini:0.34803	valid-gini:0.277742
# [400]	train-gini:0.350134	valid-gini:0.277973
# [410]	train-gini:0.352093	valid-gini:0.277972
# [420]	train-gini:0.354129	valid-gini:0.278202
# [430]	train-gini:0.356195	valid-gini:0.27814
# [440]	train-gini:0.358001	valid-gini:0.278623
# [450]	train-gini:0.360186	valid-gini:0.278652
# [460]	train-gini:0.362003	valid-gini:0.278812
# [470]	train-gini:0.363905	valid-gini:0.278896
# [480]	train-gini:0.36554	valid-gini:0.279028
# [490]	train-gini:0.367538	valid-gini:0.279035
# [500]	train-gini:0.369445	valid-gini:0.27936
# [510]	train-gini:0.371259	valid-gini:0.279684
# [520]	train-gini:0.372887	valid-gini:0.279604
# [530]	train-gini:0.374617	valid-gini:0.280012
# [540]	train-gini:0.376226	valid-gini:0.280135
# [550]	train-gini:0.378045	valid-gini:0.280362
# [560]	train-gini:0.379478	valid-gini:0.280485
# [570]	train-gini:0.381253	valid-gini:0.280585
# [580]	train-gini:0.382527	valid-gini:0.280543
# [590]	train-gini:0.383896	valid-gini:0.280597
# [600]	train-gini:0.385485	valid-gini:0.280599
# [610]	train-gini:0.386981	valid-gini:0.280664
# [620]	train-gini:0.388676	valid-gini:0.280555
# [630]	train-gini:0.390443	valid-gini:0.280546
# [640]	train-gini:0.39198	valid-gini:0.280488
# [650]	train-gini:0.393528	valid-gini:0.280733
# [660]	train-gini:0.395166	valid-gini:0.280672
# [670]	train-gini:0.396537	valid-gini:0.280802
# [680]	train-gini:0.398081	valid-gini:0.280943
# [690]	train-gini:0.399603	valid-gini:0.280771
# [700]	train-gini:0.401083	valid-gini:0.280769
# [710]	train-gini:0.402213	valid-gini:0.280912
# [720]	train-gini:0.403486	valid-gini:0.281014
# [730]	train-gini:0.404746	valid-gini:0.281029
# [740]	train-gini:0.406299	valid-gini:0.280984
# [750]	train-gini:0.407596	valid-gini:0.281114
# [760]	train-gini:0.409007	valid-gini:0.281008
# [770]	train-gini:0.410004	valid-gini:0.280843
# [780]	train-gini:0.411499	valid-gini:0.280783
# [790]	train-gini:0.413087	valid-gini:0.28071
# [800]	train-gini:0.414427	valid-gini:0.280619
# Stopping. Best iteration:
# [751]	train-gini:0.407772	valid-gini:0.281151
#
#  xgb kfold: 3  of  5 :
# [0]	train-gini:0.216059	valid-gini:0.204453
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 50 rounds.
# [10]	train-gini:0.243166	valid-gini:0.228118
# [20]	train-gini:0.251484	valid-gini:0.236569
# [30]	train-gini:0.253105	valid-gini:0.237357
# [40]	train-gini:0.255364	valid-gini:0.238978
# [50]	train-gini:0.25881	valid-gini:0.241613
# [60]	train-gini:0.259531	valid-gini:0.241914
# [70]	train-gini:0.261716	valid-gini:0.243817
# [80]	train-gini:0.263589	valid-gini:0.244301
# [90]	train-gini:0.265901	valid-gini:0.245646
# [100]	train-gini:0.266695	valid-gini:0.245858
# [110]	train-gini:0.268717	valid-gini:0.247122
# [120]	train-gini:0.27065	valid-gini:0.248153
# [130]	train-gini:0.274293	valid-gini:0.249818

# %%
params ={'learning_rate' : 0.02,
         'max_depth' : 5,
         'max_bin' : 10,
         'feature_fraction' : 0.9,
         'bagging_fraction' : 0.9,
         'bagging_frequency': 10,
         'min_data' : 500,
         'objective' : 'binary',
         'metric' : 'auc',
         'bagging_seed' : 99
}

# %%
for i, (train_index, test_index) in enumerate(stratkfold.split(x_train, y_train)):
    
    print(' light gbm kfold: {}  of  {} : '.format(i+1, kfold))    
    d_train = lgb.Dataset(x_train.iloc[train_index], label = y_train.iloc[train_index]) 
    d_valid = lgb.Dataset(x_train.iloc[test_index], label = y_train.iloc[test_index]) 
        
    model = lgb.train(params, d_train, num_round, d_valid, early_stopping_rounds = 50, 
                  feval = gini_lgb, verbose_eval = 10)
    y_pred += model.predict(x_test, num_iteration=(model.best_iteration+50) / (2*kfold))

model.save_model('lgb_model.txt')

# %%
y_pred /= (2*kfold)
submit('xgb1.csv', id_test, y_pred)
